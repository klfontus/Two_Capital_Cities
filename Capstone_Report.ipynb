# %% [markdown]
# <a href="https://colab.research.google.com/github/klfontus/Coursera_Capstone/blob/main/Capstone_Report.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # <center> Two Capital Cities: Sacramento vs. Austin Report

# %% [markdown]
# ### **Introduction**

# %% [markdown]
# Recently, there has been  discussion in the media and among political figures about the so-called "Exodus" of California resdents to other states. Texas is often reported as one of the main destinations of these migrants, as their state income tax is zero and California's is the highest in the nation. It was brought to the forefront of the nation's attention when Tesla, Inc. announced they would be moving their base of operations from its birthplace in Silicon Valley to Texas, in response to COVID-19 restrictions placed on their factory by the CA State government. This has yet to happen, but it helped to spark conversation and led to claims that California's population has been decreasing as a result of California policies.
#
# Looking at data from the US Census Bureau, although the rate has been steadily decreasing, California has always had a postive population growth from year to year. The only exception was the year 2020, which saw a 0.18% decline in population, with a net loss of about 69,500 people. Now, California is the most populous state in the country with more than 39 million people, and a loss of less than one percent of the population does not seem too significant. It still attracts new residents by the thousands every year, due to its attractive weather and its many opportunities in all career sectors. But with the population previously growing at smaller and smaller rates, and now with a negative rate of growth, we may soon be looking at a larger decline than expected.
#
# Texas and California are very different states politically, culturally, economically, and socially. It would be difficult to predict the population trends based on these factors. I am not aiming to predecit whether or not people will be moving out of state. My question is, **will California migrants coming from a particular city be able to find a new home that is similar to their last in Texas?** We will specifically look at two cities that share certain charateristics, and see if we can find things in common that would help attract people who want to move to Texas but don't want to change the quality or type of life they live.
#
# I will be comparing the capital cities of Texas and California, namely Austin and Sacramento. The main difference between them is their size. Austin has almost double the geographical and population size of Sacramento. If you take into account the Sacramento metropolitan area, they are of comparable scale. However for the purposes of this project, I would like to focus on the more urban area of the city, as I believe it will better mimic the demographics of Austin than if I also included the suburban areas. There are some important similarities though. They are both the political capitals of their state, meaning a lot of their occupants work in different administrative governmental capacities. They are also both home to large universities, which greatly influences the population, and they have a similar geographical profile, being along a river.

# %% [markdown]
# ### **Data**

# %% [markdown]
# Although my focus is on the contents of the different neighborhoods of each city, I will also be taking a quick look at raw population data. I will compare the growth of each state's population over the past twenty years and that of the two cities and see if we can predict future population trends. This data is easily attainable on different sites thanks to the US Census Bureau.
#
# The FourSqaure data will be the main thing I look at while making my analysis. I will look at the most common venues of each neighborhood and create clusters to group together similar areas. When I have created clusters to my liking for both cities, I will do a direct comparison of the clusters of each cities, to see if I can find similarities that would help attract a Sacramento resident to Austin.

# %% [markdown]
# ### **Methodology**

# %% [markdown]
# discuss and describe any exploratory data analysis that you did, any inferential statistical testing that you performed, if any, and what machine learnings were used and why.

# %% [markdown]
# ##### ***Population Analysis***

# %% [markdown]
# The very first step was to compare at the population growth trends for the cities of Austin and Sacramento, as well as of the states of Texas and California. Data for all of these come from [macrotrends.net](https://macrotrends.net), which creates tables from the US Census Bureau data. I put the raw population numbers and the population growth percentages into tables, and plotted them by plotting the cities' data and the states' data on separate graphs. Then I performed linear regression on all the data sets to see if there were overall negative or positive trends, and plotted the regression lines on them as well.

# %% [markdown]
# CA and TX Population | CA and TX Growth Rates
# -                    | -
# ![ca texas pop.png](data:image/png;base64,...)  | ![ca texas growth.png](data:image/png;base64,...)

# %% [markdown]
# Sacramento and Austin Population | Sacramento and Austin Growth Rates
# -                                | -
# ![sac austin pop.png](data:image/png;base64,...)  |  ![sac austin growth.png](data:image/png;base64,...)

# %% [markdown]
# At first look, both states and cities have upward trends in their population numbers over the past few years. The red Linear Regression line on each set of data shows not much variation of the data as there is a lot of overlap between lines. California has a much larger population which is reflected in the large gap between the two lines. It looks like the California line is plateauing, while Texas has a more steady upward slope. Sacramento has had a greater population than Austin, but the gap has been rapidly closing between the two cities. The growth percentages give us a better idea of what is happening.
#
# Texas has had a larger growth rate the past ten years. The sharp decline that started for both in 2015 is interesting, but since they match each other almost perfectly, I presume it is from an external reason that has nothing to do with our problem. But we see that since then, Califorria's growth rate has continued to decline, while Texas's has begun to rise again. Austin and Sacramento's growth rates also mirror each other, with Austin having the higher rate. Both had been holding steady-ish until 2018 where both experienced a sharp decline, and neither have increased since.
#
# For all the data, the Linear Regression Lines tell us that there is had been a trend of declining growth rate that will continue to the future.
#
# Overall, while the population continues to grow, California and Sacramento's population growth is slowing. This may be due to a "max exodus" that offsets any natural positive growth. The declines in growth were unexpected for me, but seeing that the Texas and Austin population growth has been much larger gives me confirmation that they are having a lot of people moving there.
#
# For the period of 2010 to 2020, Austin's average growth rate was 4.089, Texas's was 1.55, Sacramento's was 2.06, and California's was 0.57. For comparison, the current global population growth rate is 1%, and the United States' is 0.5%. The averages for all of our data sets is above the rate for the US, while California is the only one below the world's.
#
# People are not necessarily moving from Sacramento at a high rate, but there are plenty of people moving to Austin, and people are moving to Texas at a higher rate than to California. Our scenario of someone moving from Sacramento to Austin is not implausible, so we will continue with our venue analysis to see if we can find factors that would help people decide to move there.

# %% [markdown]
# ##### ***Sacramento and Austin Venue Analysis***

# %% [markdown]
# First I created data frames that listed the different neighborhoods of each city, which I found on [The Demogrphic Statistical Atlas of the United States](https://statisticalatlas.com). Neither city has established boroughs. Next I used Geopy to find the coordinates of each neihgborhood and add them to the data frame. This proved tricky because the neighborhoods aren't as big and don't always have the official definitions that neighborhoods in places like New York City might have. In addition, formatting each neighborhood address as *Neighborhood, State* gave me coordinates for places around the state, and in Califnoria's (CA) case, all over the world as well. Therefore I had to format the addresses as *Neighborhood, City, State*, which still gave incorrect locations for some Sacramento neighborhoods. There were only four neighborhods that I couldn't get good coordinates for, so I just dropped them from the data frame. Looking at the map afterwards, I still had good coverage of the city.
#
# Next I used the Foursquare API to find the venues that were within 1000 meters of each neighborhood. I did an initial search of venues with a much smaller radius, but some neighborhoods had a very small amount of venues. Looking at the map, the neighborhoods are not very densely packed in some areas, so I upped the radius to a little under a mile to get a more accurate picture of the larger neighborhoods. After that I did not hot encoding to get a numerical representation of the category of each venue, and averaged the venue categories for each neighborhood to see their frequency.
#
# I ran K-Means clustering on the dataset containing the frequency of the venue categories, to group them according to the similarity of venues. Clustering was the best algorithm to use in this case, as we were not trying to classify the neighborhoods based on any pre-existing labels, and using  something like K Nearest Neighbor would have grouped each neighborhood geographically which could be used to create boroughs, but it would not be helpful in this project.
#
# After this I took a look at each induvidual cluster to create a classification for each one, based on their most common venues. The numbers of the clusters of each city doesn't mean that their contents match, so you can't make a comparison that way.

# %% [markdown]
# ### **Results**

# %% [markdown]
# I ended up with 5 clusters for each city, which I labeled as such:
#
# Sacramento                            | Austin
# -                                     | -
# 0. Busy Suburban                      | 0. High Traffic/Tourist/Downtown
# 1. Non-Busy Suburban/Nature           | 1. No idea
# 2. Downtown/Shopping/High Traffic     | 2. Busy Suburbs/Eating/Tourist
# 3. Busy Suburban (Mexican community?) | 3. Airport
# 4. Outdoors                           | 4. Outdoors/Suburban
#
# I am keeping the 0-4 cluster labels to stay consistent with the labels that are in the data frame I am referencing.
#
# Sacramento had one cluster that is an outlier, **4. Outdoors**. However there is a cluster in Austin that has an Outdoors label, so we will leave it be.
#
# Austin has two outlier clusters, **1. No Idea** and **3. Airport**. Cluster number two consists of one neighborhood called **Peach Springs Springdale** which has only three venues: a discount store, a liquor store, and an electrician. It doesn't have an neighborhoods directly beside it but I wouldn't call it isolated. Because there are so few venues and there are no other neighborhoods in the cluster, I am removing it from my considerations. Similarly, cluster number four only consists of the **North Austin** which houses the airport, and only has airport related venues. Sacramento has a neighborhood called **Airport** and it is in its cluster number 2 since it included the restaurants and coffee shops in and around the airport. Because Austin's airport cluster is so singled out, I will drop it from consideration too, but take note that both cities have major airports that service the population.
#
# Thus we end up with the following clusters. I am not re-indexing the Austin clusters to stay consistent with what data frame that I am referencing
#
# Sacramento                            | Austin
# -                                     | -
# 0. Busy Suburban                      | 0. High Traffic/Tourist/Downtown
# 1. Non-Busy Suburban/Nature           | 2. Busy Suburbs/Eating/Tourist
# 2. Downtown/Shopping/High Traffic     | 4. Outdoors/Suburban
# 3. Busy Suburban (Mexican community?) |
# 4. Outdoors                           |

# %% [markdown]
# ### **Discussion**

# %% [markdown]
# We're analyzing these clusters to see if we can attract Sacramento residents to Austin, based on similarity of venues in each city. Austin is a large city with plently of job opportunities in many sectors, but we want to see if new residents can find a home there reminiscent of their last one.
#
# Sacramento has suburbs in 3/5 of its clusters and Austin has it in 2/3 in its clusters. So both cities have areas that meant more for living as oppposed to shopping or working. The "Busy Suburban" areas might be counterintuituve to the idea that suburbs are for slower paced living. They have more restaurants and retail stores, but still have places like grocery stores, parks, and gyms that indicate to me that the area is more residential than the busy shopping. They just have a higher amount of traffic due to the venues that attract people that might not live there.
#
# Both cities have one cluster that is dedicated to high traffic, busy areas that have neighborhoods that are usually in city center/downtown and have a lot of shopping options and are more touristy areas. They also are home to more coffee shops and fast food establishments, which means quick eats and drinks on the go for pedestrians.
#
# Sacramento's "Outdoor" cluster comprises of one neighborhood called **American River Parkway**, whose three venues are nature sites. Austin's "Outdoors" cluster has many parks and trails, but each neighborhood also has a few stores or restaurants, so it is not quite on the level of Sacramento's. However, it does indicate that Austin does have some natural beauty that can be found in one of these neighborhoods. Looking at the physical map of Austin, the city is near some small rivers and bodies of water. Even though there isn't a neighborhood dedicated to just nature, there are parts of the city that nature lovers will be able to enjoy.
#
# One thing that stood out to me in Sacramento's cluster 3 is that Mexican restaurants are in the top six venues categories for every neighborhood in it. Even in clusters that have a lot of restaurants, Mexican is not nearly as popular. Now this cluster has many other restaurants and small businesses, but I assume that its ain attribute is the presence of a strong Mexican community. Most of these neighborhoods are also in one geographic area, but they aren't so close that there would be an overlap in venues. The Austin cluster that would be the best comparison to this is its cluster number 2. However, it is the largest Austin cluster and it is marked by the high frequency of restaurants of varying cuisines. I would say that Mexican is the first or second most common, along with pizza places, but since this cluster is labeled to be for eating and tourists, there is bound to be a larger than average number of restaurats all together. And since Texas is in the south, Mexican food is very common there. But since there are so many of these neighborhoods and they're spread around the whole center of the city, it would be difficult to pinpoint a place that might have a Mexican community with this data.
#
# Looking at the clusters Sacramento has, a resident of that city would look to move to a place that has non-busy suburbs for relaxing and residing, busier but non-downtown areas for shopping and eating, a bustling downtown area, and areas that are away from the city where one could be in nature. It seems that Austin is a good match. There seems to be more high traffic neighborhoods than Sacramento, but the suburban areas that look to be a little more isolated make up for it. Since Austin is a much bigger city in size, and the growth rate is rising rapidly, this may change in the future as more neighborhoods are built and populatied to meet demand. Having a busy downtown is a given for cities of their sizes. The one thing that may have not made Austin a good destination is if it lacked access to nature. However, since Austin cluster 4 has trails in addition to parks and there seems to be natural formations near the city, we can assume that a nature lover's needs could be met. The one thing that Austin does seem to lack is and obvious Mexican suburban community, but it could just not be evident from the venue data. Someone looking for that would have to do their own further research.

# %% [markdown]
# ### **Conclusion**

# %% [markdown]
# In this report, we looked at the neighborhoods that are clustered together based on similar venues in both Austin in Sacramento. We found that while Austin seems to be a busier city, someone who wanted to move there from Sacramento would most likely be able to find places where they could live a similar lifestyle. Both cities have a lot of suburbs that are full of restaurants and shopping areas, but also have indicators that there are spaces for people looking for a place to live. Sacramento has more neighborhoods that have less traffic, but Austin has a few that not only are non-busy suburbs, but they are close to nature. Those neighborhoods should satisfy the people from Sacramento who are used to visiting nature venues more often. And of course, both cities have busy downtown/city centers that will appeal for people who want a faster paced lifestyle. People who come from a neighborhood with a large Mexican presence might want to do some research to find a place in Austin that could remind them of home, since non of the clusters in Austin can definitively point to something like in Sacramento.
